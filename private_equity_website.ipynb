# %%
import pandas as pd

df=pd.read_excel(r'C:\Users\jackl\Desktop\UChicago\Boutique Internship\Lauterbach & Amen\Accounting Firm M&A.xlsx')

list = []
count = 0

for i in df["Acquirer Company"]:
    if i not in list:
        list.append(i)
        string = f"https://www.google.com/search?q={i}+private+equity"
        count += 1
        for ele in range(len(string)):
            if string[ele] == " ":
                string = string[:ele] + "+" + string[ele + 1:]
            if string[ele] == "&":
                string = string[:ele] + "+" + string[ele + 1:]
        print(count, string)
# Out:
# 1 https://www.google.com/search?q=PKF+O'Connor+Davies+private+equity
# 2 https://www.google.com/search?q=Baratz+++Associates+private+equity
# 3 https://www.google.com/search?q=Citrin+Cooperman+++Company+private+equity
# 4 https://www.google.com/search?q=UHY+LLP+private+equity
# 5 https://www.google.com/search?q=Saltmarsh+Cleaveland+++Gund+private+equity
# 6 https://www.google.com/search?q=Stephano+Slack+private+equity
# 7 https://www.google.com/search?q=Aprio+LLP+private+equity
# 8 https://www.google.com/search?q=EisnerAmper+private+equity
# 9 https://www.google.com/search?q=Sikich+private+equity
# 10 https://www.google.com/search?q=Honkamp+private+equity
# 11 https://www.google.com/search?q=Ryan+private+equity
# 12 https://www.google.com/search?q=BMSS+Advisors+++CPAs+private+equity
# 13 https://www.google.com/search?q=Rosen+Sapperstein+and+Friedlander+private+equity
# 14 https://www.google.com/search?q=Eide+Bailly+private+equity
# ...
